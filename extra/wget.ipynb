# %% [markdown]
# # Mirroring websites with `wget`<a id='wget'></a>
#
# `wget` is classic (circa 1996, but still updated) [free software](https://www.gnu.org/philosophy/free-sw) in shell for non-interactively downloading web content. It's often used for basic one-time downloads, like `curl` also does for shell or `urllib.urlretrieve` does in-house for Python. But where `wget` really shines is in its extensive customization, including retrying failed connections, following links, and duplicating a remote website's files and structure to the point of having an identical local copy (website mirroring).
#
# Let's try using the nice Python wrapper for `wget` to download the MDI News page:

# %%
import wget 
wget.download(url='https://mdi.georgetown.edu/news/')
# Out:
# 'download (1).wget'

# %% [markdown]
# We can check out the contents of this (rather poorly named) file using the Jupyter interface in the previous tab.
#
# We got some HTML--cool! But what if we want something clickable and interactive? This is easiest to do with `wget` run via its native shell, rather than this simple Python wrapper--which also doesn't allow for `get`'s more advanced functionality. We can use the helpful `!` prefix to run shell commands straight from this notebook.
#
# Let's make a new `wget` request to download a version of the same page that's easier to see in your browser.

# %%
# !wget https://mdi.georgetown.edu/news/
# Out:
# --2022-07-18 20:35:13--  https://mdi.georgetown.edu/news/
# Resolving mdi.georgetown.edu (mdi.georgetown.edu)... 23.185.0.4, 2620:12a:8001::4, 2620:12a:8000::4
# Connecting to mdi.georgetown.edu (mdi.georgetown.edu)|23.185.0.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 66738 (65K) [text/html]
# Saving to: ‘index.html.1’
#
# index.html.1        100%[===================>]  65.17K  --.-KB/s    in 0.04s
#
# 2022-07-18 20:35:14 (1.81 MB/s) - ‘index.html.1’ saved [66738/66738]

# %% [markdown]
# Use your Jupyter browser to check out the results: just click on `index.html` in your current folder (probably this is `day-1/`) to view the page. What do you notice? How does it compare to viewing https://mccourt.georgetown.edu/research/mdi-news/ in your browser? Try clicking the links. Where can you go on the actual page that your local copy can't show you? Do you have local copies of the images?

# %% [markdown]
# ## Features of `wget`<a id='wget_features'></a>
#
# You might have noticed that we only ended up with some HTML--we didn't download any of the files associated with the webpage. So, this isn't a true copy; we couldn't host the page ourselves, analyze its images, or easily use its content for purposes other than viewing. How do we mirror the full site?
#
# To do this, we need only the `page-requisites` option, which makes sure to download all the resources needed to render the page in a browser: that means CSS, javascript, image files, etc. To keep from overloading the server, let's pause for a few seconds in between downloads using the `--wait` option.
#
# Let's use some other features as well for politeness and subtlety (i.e. to avoid getting blocked). Here is explanation for all of them:
#
# ```shell
# --page-requisites             Grabs all of the linked resources necessary to render the page (images, CSS, javascript, etc.)
# --wait                        Pauses between downloads (in seconds)
# --tries=3                     Retries failed downloads 3 times
# --user-agent=Mozilla          Makes wget look like a Mozilla browser by masking its user agent
# --header="Accept:text/html"   Sends header with each HTML request, looks more browser-ish
# --no-check-certificate        Doesnt check authenticity of website server (use only with trusted websites!)
# ```

# %%
# !wget --page-requisites --wait=2 --tries=3 --user-agent=Mozilla --header="Accept:text/html" --no-check-certificate \
    https://mdi.georgetown.edu/news/
# Out:
# --2022-07-18 20:35:14--  https://mdi.georgetown.edu/news/
# Resolving mdi.georgetown.edu (mdi.georgetown.edu)... 23.185.0.4, 2620:12a:8001::4, 2620:12a:8000::4
# Connecting to mdi.georgetown.edu (mdi.georgetown.edu)|23.185.0.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 66738 (65K) [text/html]
# Saving to: ‘mdi.georgetown.edu/news/index.html’
#
# mdi.georgetown.edu/ 100%[===================>]  65.17K  --.-KB/s    in 0.03s
#
# 2022-07-18 20:35:14 (2.31 MB/s) - ‘mdi.georgetown.edu/news/index.html’ saved [66738/66738]
#
# Loading robots.txt; please ignore errors.
# --2022-07-18 20:35:16--  https://mdi.georgetown.edu/robots.txt
# Reusing existing connection to mdi.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6224 (6.1K) [text/plain]
# Saving to: ‘mdi.georgetown.edu/robots.txt’
#
# mdi.georgetown.edu/ 100%[===================>]   6.08K  --.-KB/s    in 0s
#
# 2022-07-18 20:35:16 (39.4 MB/s) - ‘mdi.georgetown.edu/robots.txt’ saved [6224/6224]
#
# --2022-07-18 20:35:18--  https://mdi.georgetown.edu/wp-content/plugins/embed-gutenberg-block-google-maps/assets/css/style.836e5da587e9ec9692c0.css?ver=1658047951
# Reusing existing connection to mdi.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 743 [text/css]
# Saving to: ‘mdi.georgetown.edu/wp-content/plugins/embed-gutenberg-block-google-maps/assets/css/style.836e5da587e9ec9692c0.css?ver=1658047951’
#
# mdi.georgetown.edu/ 100%[===================>]     743  --.-KB/s    in 0s
#
# 2022-07-18 20:35:19 (20.5 MB/s) - ‘mdi.georgetown.edu/wp-content/plugins/embed-gutenberg-block-google-maps/assets/css/style.836e5da587e9ec9692c0.css?ver=1658047951’ saved [743/743]
#
# --2022-07-18 20:35:21--  https://mdi.georgetown.edu/wp-content/plugins/wp-plugin-custom-blocks/build/css/gu-custom-blocks-frontend.css?ver=1657841640
# Reusing existing connection to mdi.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1040 (1.0K) [text/css]
# Saving to: ‘mdi.georgetown.edu/wp-content/plugins/wp-plugin-custom-blocks/build/css/gu-custom-blocks-frontend.css?ver=1657841640’
#
# mdi.georgetown.edu/ 100%[===================>]   1.02K  --.-KB/s    in 0s
#
# 2022-07-18 20:35:21 (21.8 MB/s) - ‘mdi.georgetown.edu/wp-content/plugins/wp-plugin-custom-blocks/build/css/gu-custom-blocks-frontend.css?ver=1657841640’ saved [1040/1040]
#
# --2022-07-18 20:35:23--  https://mdi.georgetown.edu/wp-content/themes/wp-theme-1789/screen.css?ver=1658047952
# Reusing existing connection to mdi.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 163975 (160K) [text/css]
# Saving to: ‘mdi.georgetown.edu/wp-content/themes/wp-theme-1789/screen.css?ver=1658047952’
#
# mdi.georgetown.edu/ 100%[===================>] 160.13K  --.-KB/s    in 0.05s
#
# 2022-07-18 20:35:23 (3.03 MB/s) - ‘mdi.georgetown.edu/wp-content/themes/wp-theme-1789/screen.css?ver=1658047952’ saved [163975/163975]
#
# --2022-07-18 20:35:25--  https://mdi.georgetown.edu/wp-includes/js/jquery/jquery.min.js?ver=3.6.0
# Reusing existing connection to mdi.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 89521 (87K) [application/x-javascript]
# Saving to: ‘mdi.georgetown.edu/wp-includes/js/jquery/jquery.min.js?ver=3.6.0’
#
# mdi.georgetown.edu/ 100%[===================>]  87.42K  --.-KB/s    in 0.02s
#
# 2022-07-18 20:35:25 (5.62 MB/s) - ‘mdi.georgetown.edu/wp-includes/js/jquery/jquery.min.js?ver=3.6.0’ saved [89521/89521]
#
# --2022-07-18 20:35:27--  https://mdi.georgetown.edu/wp-includes/js/jquery/jquery-migrate.min.js?ver=3.3.2
# Reusing existing connection to mdi.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 
MB/s) - ‘mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-brands-400.eot?’ saved [133034/133034]
#
# --2022-07-18 20:35:55--  https://mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-brands-400.woff2
# Reusing existing connection to mdi.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 76612 (75K) [font/woff2]
# Saving to: ‘mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-brands-400.woff2’
#
# mdi.georgetown.edu/ 100%[===================>]  74.82K  --.-KB/s    in 0.006s
#
# 2022-07-18 20:35:55 (12.2 MB/s) - ‘mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-brands-400.woff2’ saved [76612/76612]
#
# --2022-07-18 20:35:57--  https://mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-brands-400.woff
# Reusing existing connection to mdi.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 89824 (88K) [font/woff]
# Saving to: ‘mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-brands-400.woff’
#
# mdi.georgetown.edu/ 100%[===================>]  87.72K  --.-KB/s    in 0.009s
#
# 2022-07-18 20:35:57 (9.26 MB/s) - ‘mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-brands-400.woff’ saved [89824/89824]
#
# --2022-07-18 20:35:59--  https://mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-brands-400.ttf
# Reusing existing connection to mdi.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 132728 (130K) [application/x-font-ttf]
# Saving to: ‘mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-brands-400.ttf’
#
# mdi.georgetown.edu/ 100%[===================>] 129.62K  --.-KB/s    in 0.008s
#
# 2022-07-18 20:35:59 (15.2 MB/s) - ‘mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-brands-400.ttf’ saved [132728/132728]
#
# --2022-07-18 20:36:01--  https://mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-brands-400.svg
# Reusing existing connection to mdi.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 715890 (699K) [image/svg+xml]
# Saving to: ‘mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-brands-400.svg’
#
# mdi.georgetown.edu/ 100%[===================>] 699.11K  2.18MB/s    in 0.3s
#
# 2022-07-18 20:36:02 (2.18 MB/s) - ‘mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-brands-400.svg’ saved [715890/715890]
#
# --2022-07-18 20:36:04--  https://mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-solid-900.eot
# Reusing existing connection to mdi.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 202902 (198K) [application/vnd.ms-fontobject]
# Saving to: ‘mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-solid-900.eot’
#
# mdi.georgetown.edu/ 100%[===================>] 198.15K  --.-KB/s    in 0.07s
#
# 2022-07-18 20:36:04 (2.66 MB/s) - ‘mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-solid-900.eot’ saved [202902/202902]
#
# --2022-07-18 20:36:06--  https://mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-solid-900.eot?
# Reusing existing connection to mdi.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 202902 (198K) [application/vnd.ms-fontobject]
# Saving to: ‘mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-solid-900.eot?’
#
# mdi.georgetown.edu/ 100%[===================>] 198.15K  --.-KB/s    in 0.05s
#
# 2022-07-18 20:36:06 (3.93 MB/s) - ‘mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-solid-900.eot?’ saved [202902/202902]
#
# --2022-07-18 20:36:08--  https://mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-solid-900.woff2
# Reusing existing connection to mdi.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 79444 (78K) [font/woff2]
# Saving to: ‘mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-solid-900.woff2’
#
# mdi.georgetown.edu/ 100%[===================>]  77.58K  --.-KB/s    in 0.01s
#
# 2022-07-18 20:36:08 (7.13 MB/s) - ‘mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-solid-900.woff2’ saved [79444/79444]
#
# --2022-07-18 20:36:10--  https://mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-solid-900.woff
# Reusing existing connection to mdi.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 103300 (101K) [font/woff]
# Saving to: ‘mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-solid-900.woff’
#
# mdi.georgetown.edu/ 100%[===================>] 100.88K  --.-KB/s    in 0.009s
#
# 2022-07-18 20:36:10 (10.4 MB/s) - ‘mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-solid-900.woff’ saved [103300/103300]
#
# --2022-07-18 20:36:12--  https://mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-solid-900.ttf
# Reusing existing connection to mdi.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 202616 (198K) [application/x-font-ttf]
# Saving to: ‘mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-solid-900.ttf’
#
# mdi.georgetown.edu/ 100%[===================>] 197.87K  --.-KB/s    in 0.06s
#
# 2022-07-18 20:36:12 (3.49 MB/s) - ‘mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-solid-900.ttf’ saved [202616/202616]
#
# --2022-07-18 20:36:14--  https://mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-solid-900.svg
# Reusing existing connection to mdi.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 897426 (876K) [image/svg+xml]
# Saving to: ‘mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-solid-900.svg’
#
# mdi.georgetown.edu/ 100%[===================>] 876.39K  2.05MB/s    in 0.4s
#
# 2022-07-18 20:36:15 (2.05 MB/s) - ‘mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-solid-900.svg’ saved [897426/897426]
#
# --2022-07-18 20:36:17--  https://mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-regular-400.eot
# Reusing existing connection to mdi.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 34390 (34K) [application/vnd.ms-fontobject]
# Saving to: ‘mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-regular-400.eot’
#
# mdi.georgetown.edu/ 100%[===================>]  33.58K  --.-KB/s    in 0.002s
#
# 2022-07-18 20:36:17 (13.7 MB/s) - ‘mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-regular-400.eot’ saved [34390/34390]
# --2022-07-18 20:36:19--  https://mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-regular-400.eot?
# Reusing existing connection to mdi.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 34390 (34K) [application/vnd.ms-fontobject]
# Saving to: ‘mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-regular-400.eot?’
#
# mdi.georgetown.edu/ 100%[===================>]  33.58K  --.-KB/s    in 0.002s
#
# 2022-07-18 20:36:19 (13.4 MB/s) - ‘mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-regular-400.eot?’ saved [34390/34390]
#
# --2022-07-18 20:36:21--  https://mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-regular-400.woff2
# Reusing existing connection to mdi.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13584 (13K) [font/woff2]
# Saving to: ‘mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-regular-400.woff2’
#
# mdi.georgetown.edu/ 100%[===================>]  13.27K  --.-KB/s    in 0.001s
#
# 2022-07-18 20:36:21 (14.0 MB/s) - ‘mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-regular-400.woff2’ saved [13584/13584]
#
# --2022-07-18 20:36:23--  https://mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-regular-400.woff
# Reusing existing connection to mdi.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 16800 (16K) [font/woff]
# Saving to: ‘mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-regular-400.woff’
#
# mdi.georgetown.edu/ 100%[===================>]  16.41K  --.-KB/s    in 0.002s
#
# 2022-07-18 20:36:23 (10.4 MB/s) - ‘mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-regular-400.woff’ saved [16800/16800]
#
# --2022-07-18 20:36:25--  https://mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-regular-400.ttf
# Reusing existing connection to mdi.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 34092 (33K) [application/x-font-ttf]
# Saving to: ‘mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-regular-400.ttf’
#
# mdi.georgetown.edu/ 100%[===================>]  33.29K  --.-KB/s    in 0.005s
#
# 2022-07-18 20:36:25 (6.44 MB/s) - ‘mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-regular-400.ttf’ saved [34092/34092]
#
# --2022-07-18 20:36:27--  https://mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-regular-400.svg
# Reusing existing connection to mdi.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 144322 (141K) [image/svg+xml]
# Saving to: ‘mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-regular-400.svg’
#
# mdi.georgetown.edu/ 100%[===================>] 140.94K  --.-KB/s    in 0.04s
#
# 2022-07-18 20:36:27 (3.14 MB/s) - ‘mdi.georgetown.edu/wp-content/pattern-library/build/webfonts/fa-regular-400.svg’ saved [144322/144322]
#
# --2022-07-18 20:36:29--  https://mdi.georgetown.edu/wp-content/pattern-library/build/images/icons.svg
# Reusing existing connection to mdi.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6056 (5.9K) [image/svg+xml]
# Saving to: ‘mdi.georgetown.edu/wp-content/pattern-library/build/images/icons.svg’
#
# mdi.georgetown.edu/ 100%[===================>]   5.91K  --.-KB/s    in 0s
#
# 2022-07-18 20:36:30 (164 MB/s) - ‘mdi.georgetown.edu/wp-content/pattern-library/build/images/icons.svg’ saved [6056/6056]
#
# --2022-07-18 20:36:32--  https://mdi.georgetown.edu/wp-content/pattern-library/build/images/seal.svg
# Reusing existing connection to mdi.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 229536 (224K) [image/svg+xml]
# Saving to: ‘mdi.georgetown.edu/wp-content/pattern-library/build/images/seal.svg’
#
# mdi.georgetown.edu/ 100%[===================>] 224.16K  --.-KB/s    in 0.08s
#
# 2022-07-18 20:36:32 (2.68 MB/s) - ‘mdi.georgetown.edu/wp-content/pattern-library/build/images/seal.svg’ saved [229536/229536]
#
# FINISHED --2022-07-18 20:36:32--
# Total wall clock time: 1m 18s
# Downloaded: 36 files, 8.5M in 3.8s (2.25 MB/s)

# %% [markdown]
# Check out the results--what's similar and whats different? See `/research/mdi-news/` for the `index.html` (sometimes this is `default.html`) page we saw earlier.
#
# `wget` has a rich array of options. Here are some of the most useful ones in addition to those above:
#
# ```shell
# --mirror                      Downloads a full website and makes available for local viewing
# --recursive                   Recursively downloads files and follows links
# --no-parent 		          Does not follow links above hierarchical level of input URL
# --convert-links 	          Turns links into local links as appropriate
# --accept                      Download only file suffixes in this list (e.g., .html)
# --execute robots=off          Turns off automatic robots.txt checking, preventing server privacy exclusions
# --random-wait                 Randomizes the defined wait period to between .5 and 1.5x that value
# --background		          For a huge download, put the download in background
# --spider                      Determines whether the remote file exist at the destination (mimics web spiders)
# --domains   		          Downloads only only PDF files from specific domains
# --user --password   		  Downloads files from password protected sites
# ```

# %% [markdown]
# ### Challenge
#
# Download only `.html` files from https://mccourt.georgetown.edu/research/ and links below that.

# %%
# Solution
# !wget --accept .html --recursive --no-parent --page-requisites --convert-links --wait=2 --tries=3 \
    --user-agent=Mozilla --header="Accept:text/html" --no-check-certificate \
    https://mccourt.georgetown.edu/research/
# Out:
# --2022-07-18 20:36:32--  https://mccourt.georgetown.edu/research/
# Resolving mccourt.georgetown.edu (mccourt.georgetown.edu)... 23.185.0.1, 2620:12a:8001::1, 2620:12a:8000::1
# Connecting to mccourt.georgetown.edu (mccourt.georgetown.edu)|23.185.0.1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 169630 (166K) [text/html]
# Saving to: ‘mccourt.georgetown.edu/research/index.html’
#
# mccourt.georgetown. 100%[===================>] 165.65K  --.-KB/s    in 0.09s
#
# 2022-07-18 20:36:32 (1.87 MB/s) - ‘mccourt.georgetown.edu/research/index.html’ saved [169630/169630]
#
# Loading robots.txt; please ignore errors.
# --2022-07-18 20:36:34--  https://mccourt.georgetown.edu/robots.txt
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 116 [text/plain]
# Saving to: ‘mccourt.georgetown.edu/robots.txt.tmp’
#
# mccourt.georgetown. 100%[===================>]     116  --.-KB/s    in 0s
#
# 2022-07-18 20:36:34 (1.30 MB/s) - ‘mccourt.georgetown.edu/robots.txt.tmp’ saved [116/116]
#
# --2022-07-18 20:36:36--  https://mccourt.georgetown.edu/research/featured-publications/
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 166117 (162K) [text/html]
# Saving to: ‘mccourt.georgetown.edu/research/featured-publications/index.html’
#
# mccourt.georgetown. 100%[===================>] 162.22K  --.-KB/s    in 0.02s
#
# 2022-07-18 20:36:36 (6.48 MB/s) - ‘mccourt.georgetown.edu/research/featured-publications/index.html’ saved [166117/166117]
#
# --2022-07-18 20:36:38--  https://mccourt.georgetown.edu/research/mccourt-centers/
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 158014 (154K) [text/html]
# Saving to: ‘mccourt.georgetown.edu/research/mccourt-centers/index.html’
#
# mccourt.georgetown. 100%[===================>] 154.31K  --.-KB/s    in 0.05s
#
# 2022-07-18 20:36:38 (2.92 MB/s) - ‘mccourt.georgetown.edu/research/mccourt-centers/index.html’ saved [158014/158014]
#
# --2022-07-18 20:36:40--  https://mccourt.georgetown.edu/research/research-data-center/
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 158841 (155K) [text/html]
# Saving to: ‘mccourt.georgetown.edu/research/research-data-center/index.html’
#
# mccourt.georgetown. 100%[===================>] 155.12K  --.-KB/s    in 0.02s
#
# 2022-07-18 20:36:41 (8.60 MB/s) - ‘mccourt.georgetown.edu/research/research-data-center/index.html’ saved [158841/158841]
#
# --2022-07-18 20:36:43--  https://mccourt.georgetown.edu/research/faculty-seminars/
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 169393 (165K) [text/html]
# Saving to: ‘mccourt.georgetown.edu/research/faculty-seminars/index.html’
#
# mccourt.georgetown. 100%[===================>] 165.42K  --.-KB/s    in 0.05s
#
# 2022-07-18 20:36:43 (3.29 MB/s) - ‘mccourt.georgetown.edu/research/faculty-seminars/index.html’ saved [169393/169393]
#
# --2022-07-18 20:36:45--  https://mccourt.georgetown.edu/research/the-massive-data-institute/
# Reusing existing connection to mccourt.georgetown.edu:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https
443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://mdi.georgetown.edu/advancing-research/ [following]
# --2022-07-18 20:37:04--  https://mdi.georgetown.edu/advancing-research/
# Connecting to mdi.georgetown.edu (mdi.georgetown.edu)|23.185.0.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 70979 (69K) [text/html]
# Saving to: ‘mccourt.georgetown.edu/research/the-massive-data-institute/mdi-research/index.html’
#
# mccourt.georgetown. 100%[===================>]  69.32K  --.-KB/s    in 0.03s
#
# 2022-07-18 20:37:05 (2.25 MB/s) - ‘mccourt.georgetown.edu/research/the-massive-data-institute/mdi-research/index.html’ saved [70979/70979]
#
# FINISHED --2022-07-18 20:37:05--
# Total wall clock time: 33s
# Downloaded: 14 files, 1.8M in 0.5s (3.56 MB/s)
# Converting links in mccourt.georgetown.edu/research/faculty-seminars/index.html... 39-8
# Converting links in mccourt.georgetown.edu/research/research-data-center/administrative-data-metadata/index.html... 34-8
# Converting links in mccourt.georgetown.edu/research/the-massive-data-institute/index.html... 19-3
# Converting links in mccourt.georgetown.edu/research/featured-publications/index.html... 25-8
# Converting links in mccourt.georgetown.edu/research/mccourt-centers/index.html... 31-8
# Converting links in mccourt.georgetown.edu/research/research-data-center/index.html... 41-8
# Converting links in mccourt.georgetown.edu/research/index.html... 28-12
# Converting links in mccourt.georgetown.edu/research/research-data-center/research/index.html... 34-8
# Converting links in mccourt.georgetown.edu/research/research-data-center/data-and-software-available/index.html... 34-8
# Converting links in mccourt.georgetown.edu/research/mccourt-centers/research-center-directors/index.html... 25-8
# Converting links in mccourt.georgetown.edu/research/research-data-center/contact-us/index.html... 34-8
# Converting links in mccourt.georgetown.edu/research/the-massive-data-institute/mdi-research/index.html... 17-3
# Converting links in mccourt.georgetown.edu/research/research-data-center/getting-started/index.html... 34-8
# Converted links in 13 files in 0.3 seconds.

# %% [markdown]
# ### Challenge
#
# Use advanced options for `wget` (listed above) to mirror a website you use often. Be sure to use a polite `--wait` and avoid downloading anything with massive numbers of links, files, or pages (e.g., don't try YouTube.com or Wikipedia.com). If you want to download a segment or specific page within a website (e.g., a single YouTube channel or Wikipedia page), use the `--recursive` option with `--no-parent` (to follow only links within the input URL).
#
# While you let `wget` run, read more about it on its [manual](https://www.gnu.org/software/wget/manual/wget.html) and see other examples of `wget` usage [here](https://gist.github.com/bueckl/bd0a1e7a30bc8e2eeefd) and [here](https://phoenixnap.com/kb/wget-command-with-examples).

# %%
# Solution
# !wget --mirror --recursive --no-parent --page-requisites --convert-links --wait=2 --tries=3 \
    --user-agent=Mozilla --header="Accept:text/html" --no-check-certificate \
    https://www.jarenhaber.com/
# Out:
# --2022-07-18 20:37:05--  https://www.jarenhaber.com/
# Resolving www.jarenhaber.com (www.jarenhaber.com)... 68.183.29.183, 157.245.84.7, 2604:a880:400:d0::1561:9001, ...
# Connecting to www.jarenhaber.com (www.jarenhaber.com)|68.183.29.183|:443... connected.
# HTTP request sent, awaiting response... 304 Not Modified
# File ‘www.jarenhaber.com/index.html’ not modified on server. Omitting download.
#
# Converted links in 0 files in 0 seconds.
